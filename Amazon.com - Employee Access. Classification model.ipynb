# %%
#Importing Required Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Importing Dataset
dataset = pd.read_csv('/Users/rajeshsahu/Desktop/Data Science Learning/DataSciencePython Projects/Practice Projects/Amazon.com - Employee Access./train.csv')

# %%
#printing dataset
dataset
# Out:
#        ACTION  RESOURCE  MGR_ID  ROLE_ROLLUP_1  ROLE_ROLLUP_2  ROLE_DEPTNAME  \
# 0           1     39353   85475         117961         118300         123472
# 1           1     17183    1540         117961         118343         123125
# 2           1     36724   14457         118219         118220         117884
# 3           1     36135    5396         117961         118343         119993
# 4           1     42680    5905         117929         117930         119569
# ...       ...       ...     ...            ...            ...            ...
# 32764       1     23497   16971         117961         118300         119993
# 32765       1     25139  311198          91261         118026         122392
# 32766       1     34924   28805         117961         118327         120299
# 32767       1     80574   55643         118256         118257         117945
# 32768       1     14354   59575         117916         118150         117920
#
# ...

# %%
#printing Info of dataset
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32769 entries, 0 to 32768
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ACTION            32769 non-null  int64
#  1   RESOURCE          32769 non-null  int64
#  2   MGR_ID            32769 non-null  int64
#  3   ROLE_ROLLUP_1     32769 non-null  int64
#  4   ROLE_ROLLUP_2     32769 non-null  int64
#  5   ROLE_DEPTNAME     32769 non-null  int64
#  6   ROLE_TITLE        32769 non-null  int64
#  7   ROLE_FAMILY_DESC  32769 non-null  int64
#  8   ROLE_FAMILY       32769 non-null  int64
#  9   ROLE_CODE         32769 non-null  int64
# dtypes: int64(10)
# memory usage: 2.5 MB

# %%
#Describing dataset
dataset.describe()
# Out:
#              ACTION       RESOURCE         MGR_ID  ROLE_ROLLUP_1  \
# count  32769.000000   32769.000000   32769.000000   32769.000000
# mean       0.942110   42923.916171   25988.957979  116952.627788
# std        0.233539   34173.892702   35928.031650   10875.563591
# min        0.000000       0.000000      25.000000    4292.000000
# 25%        1.000000   20299.000000    4566.000000  117961.000000
# 50%        1.000000   35376.000000   13545.000000  117961.000000
# 75%        1.000000   74189.000000   42034.000000  117961.000000
# max        1.000000  312153.000000  311696.000000  311178.000000
#
#        ROLE_ROLLUP_2  ROLE_DEPTNAME     ROLE_TITLE  ROLE_FAMILY_DESC  \
# count   32769.000000   32769.000000   32769.000000      32769.000000
# mean   118301.823156  118912.779914  125916.152644     170178.369648
# std      4551.588572   18961.322917   31036.465825      69509.462130
# min     23779.000000    4674.000000  117879.000000       4673.000000
# ...

# %%
#finding correlation between all the features
corr_df = dataset.corr(method='pearson')

# %%
#printing correlation metrix
corr_df
# Out:
#                     ACTION  RESOURCE    MGR_ID  ROLE_ROLLUP_1  ROLE_ROLLUP_2  \
# ACTION            1.000000  0.000185 -0.005167      -0.013702       0.005179
# RESOURCE          0.000185  1.000000  0.011088      -0.005016       0.013438
# MGR_ID           -0.005167  0.011088  1.000000      -0.007132      -0.000364
# ROLE_ROLLUP_1    -0.013702 -0.005016 -0.007132       1.000000       0.033358
# ROLE_ROLLUP_2     0.005179  0.013438 -0.000364       0.033358       1.000000
# ROLE_DEPTNAME     0.001025  0.030004 -0.009551      -0.009548      -0.006056
# ROLE_TITLE       -0.010169  0.002936  0.017864       0.010207       0.008305
# ROLE_FAMILY_DESC  0.003565  0.021029 -0.018488      -0.007546       0.018873
# ROLE_FAMILY       0.000502  0.031060 -0.118254       0.029468       0.069558
# ROLE_CODE         0.017147  0.007733 -0.004067      -0.024927       0.015117
#
#                   ROLE_DEPTNAME  ROLE_TITLE  ROLE_FAMILY_DESC  ROLE_FAMILY  \
# ...

# %%
plt.figure(figsize=(13,7))
sns.heatmap(corr_df,annot=True,fmt='0.1g',linecolor='black',linewidths=1).set(title='Correlation Between All Features')
plt.show()

# %% [markdown]
# None of the feature is highly correlated with others.

# %%
#plotting Actions
sns.catplot(data=dataset,x=dataset.ACTION,kind='count')

# %%
#counting 1 and 0 action
print(dataset.groupby('ACTION').get_group(0).value_counts())
# Out:
# ACTION  RESOURCE  MGR_ID  ROLE_ROLLUP_1  ROLE_ROLLUP_2  ROLE_DEPTNAME  ROLE_TITLE  ROLE_FAMILY_DESC  ROLE_FAMILY  ROLE_CODE
# 0       0         71215   117961         118386         118404         118784      118785            290919       118786       1
#         42202     3838    117961         118225         119924         118321      118448            290919       118322       1
#         42870     5228    119596         119597         168533         120789      301124            118424       120791       1
#         42710     18096   118256         118257         118623         118995      286106            292795       118997       1
#                   18073   118256         118257         118623         118995      286106            292795       118997       1
#                                                                                                                               ..
# ...

# %%
dataset.groupby('ACTION').describe()
# Out:
#        RESOURCE                                                               \
#           count          mean           std  min      25%      50%       75%
# ACTION
# 0        1897.0  42898.348972  35796.888757  0.0  20897.0  34924.0  52015.00
# 1       30872.0  42925.487205  34072.248084  0.0  20299.0  35376.0  74278.25
#
#                    MGR_ID                ... ROLE_FAMILY           ROLE_CODE  \
#              max    count          mean  ...         75%       max     count
# ACTION                                   ...
# 0       312132.0   1897.0  26737.799157  ...    290919.0  308574.0    1897.0
# 1       312153.0  30872.0  25942.943735  ...    290919.0  308574.0   30872.0
#
#                                                                             \
#                  mean          std       min       25%       50%       75%
# ACTION
# 0       119389.313126  3468.899456  117880.0  118276.0  118399.0  118997.0
# ...

# %% [markdown]
# No. of Action 0 is 1892
# No. of Action 1 is 30872
# No. of Action 0 is 5.8 % of the total train dataset

# %%
#plotting Regression graph between all the variables
plt.figure(figsize=(40,29))
sns.set_style(style='whitegrid')
dataset_plot = sns.PairGrid(dataset,hue='ACTION')
dataset_plot.map(sns.regplot)
dataset_plot.add_legend()
plt.show()

# %%
#Analysing Action 0
action_0 = dataset.groupby('ACTION').get_group(0)

# %%
action_0
# Out:
#        ACTION  RESOURCE  MGR_ID  ROLE_ROLLUP_1  ROLE_ROLLUP_2  ROLE_DEPTNAME  \
# 5           0     45333   14561         117951         117952         118008
# 41          0     74310   49521         117961         118300         118301
# 55          0     78106   50613         117916         118150         118810
# 66          0     35043   14800         117961         117962         118352
# 68          0     15716   18073         118256         118257         118623
# ...       ...       ...     ...            ...            ...            ...
# 32645       0     25749   14348         118169         118170         118623
# 32661       0     25993    7243         117961         118343         118609
# 32681       0     14925   20361         117961         117962         118352
# 32707       0     41470   14289         118602         118603         117941
# 32713       0     77202    6982         117961         118300         118783
#
# ...

# %%
#printing action 1 sampled data
action_0.shape
# Out:
# (1897, 10)

# %%
action_0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1897 entries, 5 to 32713
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ACTION            1897 non-null   int64
#  1   RESOURCE          1897 non-null   int64
#  2   MGR_ID            1897 non-null   int64
#  3   ROLE_ROLLUP_1     1897 non-null   int64
#  4   ROLE_ROLLUP_2     1897 non-null   int64
#  5   ROLE_DEPTNAME     1897 non-null   int64
#  6   ROLE_TITLE        1897 non-null   int64
#  7   ROLE_FAMILY_DESC  1897 non-null   int64
#  8   ROLE_FAMILY       1897 non-null   int64
#  9   ROLE_CODE         1897 non-null   int64
# dtypes: int64(10)
# memory usage: 163.0 KB

# %% [markdown]
# There is no null value in the 0 group and no of the rows in group is 1897

# %%
action_0.describe()
# Out:
#        ACTION       RESOURCE         MGR_ID  ROLE_ROLLUP_1  ROLE_ROLLUP_2  \
# count  1897.0    1897.000000    1897.000000    1897.000000    1897.000000
# mean      0.0   42898.348972   26737.799157  117553.749605  118206.734844
# std       0.0   35796.888757   32238.816523    6509.927394    6976.743628
# min       0.0       0.000000      25.000000    5110.000000   31010.000000
# 25%       0.0   20897.000000    4965.000000  117961.000000  118052.000000
# 50%       0.0   34924.000000   16588.000000  117961.000000  118300.000000
# 75%       0.0   52015.000000   46663.000000  118169.000000  118386.000000
# max       0.0  312132.000000  310767.000000  130570.000000  286791.000000
#
#        ROLE_DEPTNAME     ROLE_TITLE  ROLE_FAMILY_DESC    ROLE_FAMILY  \
# count    1897.000000    1897.000000       1897.000000    1897.000000
# mean   118834.391144  127189.345809     169178.854507  183499.856089
# std     16208.249258   35073.304031      71651.482980  111003.537824
# ...

# %% [markdown]
# It represents the min max standard deviation and count of each column

# %%
#plotting Actions
sns.catplot(data=dataset,x=dataset.ACTION,kind='count')

# %%
#storing all action 1 rows in a df
action_1 = dataset.groupby('ACTION').get_group(1)

# %%
action_1
# Out:
#        ACTION  RESOURCE  MGR_ID  ROLE_ROLLUP_1  ROLE_ROLLUP_2  ROLE_DEPTNAME  \
# 0           1     39353   85475         117961         118300         123472
# 1           1     17183    1540         117961         118343         123125
# 2           1     36724   14457         118219         118220         117884
# 3           1     36135    5396         117961         118343         119993
# 4           1     42680    5905         117929         117930         119569
# ...       ...       ...     ...            ...            ...            ...
# 32764       1     23497   16971         117961         118300         119993
# 32765       1     25139  311198          91261         118026         122392
# 32766       1     34924   28805         117961         118327         120299
# 32767       1     80574   55643         118256         118257         117945
# 32768       1     14354   59575         117916         118150         117920
#
# ...

# %%
#sampling action 1 rows
sampled_action_1 = action_1.sample(1897)

# %%
#printing action 1 sampled data
sampled_action_1.shape
# Out:
# (1897, 10)

# %%
#Joining both datasets action_0 and sampled_action_1
new_dataset = action_0.append(sampled_action_1,sort=True)
len(new_dataset)
# Out:
# 3794

# %%
#mixing up the rows
new_dataset = new_dataset.sample(len(new_dataset))
new_dataset
# Out:
#        ACTION  MGR_ID  RESOURCE  ROLE_CODE  ROLE_DEPTNAME  ROLE_FAMILY  \
# 933         0   51345     75901     118705         120417       118704
# 7248        0   50952     40059     118322         118929       290919
# 14749       0   15616     20218     118997         118623       292795
# 3315        1   71391      4675     117908         118522       290919
# 20798       0   16244     23497     118786         120318       290919
# ...       ...     ...       ...        ...            ...          ...
# 22668       0   49374     18072     119082         118754       292795
# 12326       0   52687     80203     119348         118910         4673
# 31988       1    1398      2997     118786         118437       290919
# 12711       0   11988     13878     117880         117941        19721
# 8581        0   13441     18072     118209         122870       270488
#
#        ROLE_FAMILY_DESC  ROLE_ROLLUP_1  ROLE_ROLLUP_2  ROLE_TITLE
# ...

# %%
#extracting features
X_feature = new_dataset.drop('ACTION',axis=1).values

# %%
Y_target = new_dataset['ACTION'].values

# %%
#Importing Modules for Prediction
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
logReg = LogisticRegression()
sc = StandardScaler()

# %%
#spliting training and test data
X_train,X_test,Y_train,Y_test = train_test_split(X_feature,Y_target)

# %%
#fitting the standard scaler module
sc.fit(X_train)
# Out:
# StandardScaler()

# %%
#transforming training data into stander scaler
X_train = sc.transform(X_train)

# %%
#training the logistic regression model
logReg.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %%
#making prediction from the model
Y_predict = logReg.predict(sc.transform(X_test))

# %%
#Eveluating ther Logistic Regression model
from sklearn.metrics import accuracy_score,average_precision_score,recall_score,confusion_matrix,f1_score,classification_report

# %%
print('Logistic Regression Model with Standardization')
print('Accuracy Score is     ',accuracy_score(Y_test,Y_predict))
print('Precision Score is    ',average_precision_score(Y_test,Y_predict))
print('Recall Score is       ',recall_score(Y_test,Y_predict))
print('Confusion Metrix is   ')
print(confusion_matrix(Y_test,Y_predict))
print('F1 Score is           ',f1_score(Y_test,Y_predict))
print (classification_report(Y_test,Y_predict))
# Out:
# Logistic Regression Model with Standardization
# Accuracy Score is      0.5194942044257113
# Precision Score is     0.5366148203111286
# Recall Score is        0.3373737373737374
# Confusion Metrix is
# [[326 128]
#  [328 167]]
# F1 Score is            0.4227848101265823
#               precision    recall  f1-score   support
#
#            0       0.50      0.72      0.59       454
#            1       0.57      0.34      0.42       495
#
#     accuracy                           0.52       949
#    macro avg       0.53      0.53      0.51       949
# weighted avg       0.53      0.52      0.50       949

# %%
#using knn classifier
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=5)

# %%
#fitting knn model
knn.fit(X_train,Y_train)
# Out:
# KNeighborsClassifier()

# %%
#making prediction from the KNNeighbors model
Y_predict = knn.predict(sc.transform(X_test))

# %%
print('KN Neighbors Model with Standardization')
print('Accuracy Score is     ',accuracy_score(Y_test,Y_predict))
print('Precision Score is    ',average_precision_score(Y_test,Y_predict))
print('Recall Score is       ',recall_score(Y_test,Y_predict))
print('Confusion Metrix is   ')
print(confusion_matrix(Y_test,Y_predict))
print('F1 Score is           ',f1_score(Y_test,Y_predict))
print (classification_report(Y_test,Y_predict))
# Out:
# KN Neighbors Model with Standardization
# Accuracy Score is      0.6290832455216017
# Precision Score is     0.6048017337632083
# Recall Score is        0.5858585858585859
# Confusion Metrix is
# [[307 147]
#  [205 290]]
# F1 Score is            0.6223175965665235
#               precision    recall  f1-score   support
#
#            0       0.60      0.68      0.64       454
#            1       0.66      0.59      0.62       495
#
#     accuracy                           0.63       949
#    macro avg       0.63      0.63      0.63       949
# weighted avg       0.63      0.63      0.63       949

# %%
#importing Decision tree Model with criterion gini
from sklearn.tree import DecisionTreeClassifier
dectree = DecisionTreeClassifier(criterion='gini',random_state = 20)

# %%
dectree.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier(random_state=20)

# %%
Y_predict = dectree.predict(sc.transform(X_test))

# %%
print('Decision Tree(gini) Model with Standardization')
print('Accuracy Score is     ',accuracy_score(Y_test,Y_predict))
print('Precision Score is    ',average_precision_score(Y_test,Y_predict))
print('Recall Score is       ',recall_score(Y_test,Y_predict))
print('Confusion Metrix is   ')
print(confusion_matrix(Y_test,Y_predict))
print('F1 Score is           ',f1_score(Y_test,Y_predict))
print (classification_report(Y_test,Y_predict))
# Out:
# Decision Tree(gini) Model with Standardization
# Accuracy Score is      0.7017913593256059
# Precision Score is     0.6630978034464958
# Recall Score is        0.6808080808080809
# Confusion Metrix is
# [[329 125]
#  [158 337]]
# F1 Score is            0.7042842215256009
#               precision    recall  f1-score   support
#
#            0       0.68      0.72      0.70       454
#            1       0.73      0.68      0.70       495
#
#     accuracy                           0.70       949
#    macro avg       0.70      0.70      0.70       949
# weighted avg       0.70      0.70      0.70       949

# %%
#decision tree with entropy
dt = DecisionTreeClassifier(criterion='entropy',random_state=20)

# %%
dt.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=20)

# %%
Y_predict = dt.predict(sc.transform(X_test))

# %%
print('Decision Tree(entropy) Model with Standardization')
print('Accuracy Score is     ',accuracy_score(Y_test,Y_predict))
print('Precision Score is    ',average_precision_score(Y_test,Y_predict))
print('Recall Score is       ',recall_score(Y_test,Y_predict))
print('Confusion Metrix is   ')
print(confusion_matrix(Y_test,Y_predict))
print('F1 Score is           ',f1_score(Y_test,Y_predict))
print (classification_report(Y_test,Y_predict))
# Out:
# Decision Tree(entropy) Model with Standardization
# Accuracy Score is      0.6965226554267651
# Precision Score is     0.6575395616900421
# Recall Score is        0.6828282828282828
# Confusion Metrix is
# [[323 131]
#  [157 338]]
# F1 Score is            0.7012448132780082
#               precision    recall  f1-score   support
#
#            0       0.67      0.71      0.69       454
#            1       0.72      0.68      0.70       495
#
#     accuracy                           0.70       949
#    macro avg       0.70      0.70      0.70       949
# weighted avg       0.70      0.70      0.70       949

# %%
#importing Naive Bayes Model
from sklearn.naive_bayes import BernoulliNB
NB = BernoulliNB()

# %%
NB.fit(X_train,Y_train)
# Out:
# BernoulliNB()

# %%
Y_predict = NB.predict(sc.transform(X_test))

# %%
print('Bernouli Naive Bayes) Model with Standardization')
print('Accuracy Score is     ',accuracy_score(Y_test,Y_predict))
print('Precision Score is    ',average_precision_score(Y_test,Y_predict))
print('Recall Score is       ',recall_score(Y_test,Y_predict))
print('Confusion Metrix is   ')
print(confusion_matrix(Y_test,Y_predict))
print('F1 Score is           ',f1_score(Y_test,Y_predict))
print (classification_report(Y_test,Y_predict))
# Out:
# Bernouli Naive Bayes) Model with Standardization
# Accuracy Score is      0.530031612223393
# Precision Score is     0.5404533435032272
# Recall Score is        0.42424242424242425
# Confusion Metrix is
# [[293 161]
#  [285 210]]
# F1 Score is            0.4849884526558892
#               precision    recall  f1-score   support
#
#            0       0.51      0.65      0.57       454
#            1       0.57      0.42      0.48       495
#
#     accuracy                           0.53       949
#    macro avg       0.54      0.53      0.53       949
# weighted avg       0.54      0.53      0.52       949

# %%
#using svm model
from sklearn import svm
clf = svm.SVC()

# %%
clf.fit(X_train,Y_train)
# Out:
# SVC()

# %%
Y_predict = clf.predict(sc.transform(X_test))

# %%
print('SVM Classifier Model with Standardization')
print('Accuracy Score is     ',accuracy_score(Y_test,Y_predict))
print('Precision Score is    ',average_precision_score(Y_test,Y_predict))
print('Recall Score is       ',recall_score(Y_test,Y_predict))
print('Confusion Metrix is   ')
print(confusion_matrix(Y_test,Y_predict))
print('F1 Score is           ',f1_score(Y_test,Y_predict))
print (classification_report(Y_test,Y_predict))
# Out:
# SVM Classifier Model with Standardization
# Accuracy Score is      0.58377239199157
# Precision Score is     0.5712358438022154
# Recall Score is        0.5575757575757576
# Confusion Metrix is
# [[278 176]
#  [219 276]]
# F1 Score is            0.5828933474128828
#               precision    recall  f1-score   support
#
#            0       0.56      0.61      0.58       454
#            1       0.61      0.56      0.58       495
#
#     accuracy                           0.58       949
#    macro avg       0.58      0.58      0.58       949
# weighted avg       0.59      0.58      0.58       949

# %%
#using randome forest classifier
from sklearn.ensemble import RandomForestClassifier
ranfo_gini = RandomForestClassifier(criterion='gini')

# %%
ranfo_gini.fit(X_train,Y_train)
# Out:
# RandomForestClassifier()

# %%
Y_predict = ranfo_gini.predict(sc.transform(X_test))

# %%
print('Random Forest(gini) Model with Standardization')
print('Accuracy Score is     ',accuracy_score(Y_test,Y_predict))
print('Precision Score is    ',average_precision_score(Y_test,Y_predict))
print('Recall Score is       ',recall_score(Y_test,Y_predict))
print('Confusion Metrix is   ')
print(confusion_matrix(Y_test,Y_predict))
print('F1 Score is           ',f1_score(Y_test,Y_predict))
print (classification_report(Y_test,Y_predict))
# Out:
# Random Forest(gini) Model with Standardization
# Accuracy Score is      0.7629083245521602
# Precision Score is     0.7172270651722706
# Recall Score is        0.7636363636363637
# Confusion Metrix is
# [[346 108]
#  [117 378]]
# F1 Score is            0.7706422018348624
#               precision    recall  f1-score   support
#
#            0       0.75      0.76      0.75       454
#            1       0.78      0.76      0.77       495
#
#     accuracy                           0.76       949
#    macro avg       0.76      0.76      0.76       949
# weighted avg       0.76      0.76      0.76       949

# %%
ranfo_entropy = RandomForestClassifier(criterion='entropy')

# %%
ranfo_entropy.fit(X_train,Y_train)
# Out:
# RandomForestClassifier(criterion='entropy')

# %%
Y_predict = ranfo_entropy.predict(sc.transform(X_test))

# %%
print('Random Forest (entropy) Model with Standardization')
print('Accuracy Score is     ',accuracy_score(Y_test,Y_predict))
print('Precision Score is    ',average_precision_score(Y_test,Y_predict))
print('Recall Score is       ',recall_score(Y_test,Y_predict))
print('Confusion Metrix is   ')
print(confusion_matrix(Y_test,Y_predict))
print('F1 Score is           ',f1_score(Y_test,Y_predict))
print (classification_report(Y_test,Y_predict))
# Out:
# Random Forest (entropy) Model with Standardization
# Accuracy Score is      0.7513171759747103
# Precision Score is     0.7077187985450423
# Recall Score is        0.7414141414141414
# Confusion Metrix is
# [[346 108]
#  [128 367]]
# F1 Score is            0.756701030927835
#               precision    recall  f1-score   support
#
#            0       0.73      0.76      0.75       454
#            1       0.77      0.74      0.76       495
#
#     accuracy                           0.75       949
#    macro avg       0.75      0.75      0.75       949
# weighted avg       0.75      0.75      0.75       949

# %% [markdown]
# # Clearly - Randome Forest Algorithm with criterion gini gives best accuracy and performs better .

# %%
#Importing test Dataset
test_dataset = pd.read_csv('/Users/rajeshsahu/Desktop/Data Science Learning/DataSciencePython Projects/Practice Projects/Amazon.com - Employee Access./test.csv')

# %%
test_dataset
# Out:
#             id  RESOURCE  MGR_ID  ROLE_ROLLUP_1  ROLE_ROLLUP_2  ROLE_DEPTNAME  \
# 0            1     32642    7792         118573         118574         117945
# 1            2      4696   14638         117961         118343         118514
# 2            3     22662    1760         118887         118888         120171
# 3            4     75078    7576         117961         118052         120671
# 4            5     39879   55668         117902         118041         117945
# ...        ...       ...     ...            ...            ...            ...
# 912358  912359     32642    7792         118573         118574         117945
# 912359  912360     41594   25262         126974         126975         118320
# 912360  912361     45784     141         117961         118225         122273
# 912361  912362     15716    2456         118752         118753         118754
# 912362  912363     43443    7022         119062         119091         118535
#
# ...

# %%
#randome forest prediction with test dataset
test_dataset.drop('id',axis=1,inplace=True)

# %%
test_dataset.head()
# Out:
#    RESOURCE  MGR_ID  ROLE_ROLLUP_1  ROLE_ROLLUP_2  ROLE_DEPTNAME  ROLE_TITLE  \
# 0     32642    7792         118573         118574         117945      136261
# 1      4696   14638         117961         118343         118514      118321
# 2     22662    1760         118887         118888         120171      118396
# 3     75078    7576         117961         118052         120671      118321
# 4     39879   55668         117902         118041         117945      135951
#
#    ROLE_FAMILY_DESC  ROLE_FAMILY  ROLE_CODE
# 0            128463       292795     119082
# 1            289122       255851     118322
# 2            255118       118398     118399
# 3            117906       257051     118322
# 4            134458        19776     119082

# %%
test_dataset.shape
# Out:
# (912363, 9)

# %%
print(ranfo_gini.predict(sc.transform(test_dataset)))
# Out:
# [1 1 1 ... 0 1 1]

# %% [markdown]
# # random forest prediction with biased training dataset

# %%
##random forest prediction with biased training dataset
#plotting Actions
sns.catplot(data=dataset,x=dataset.ACTION,kind='count')

# %%
X = dataset.drop('ACTION',axis=1).values

# %%
Y = dataset.ACTION.values

# %%
#spliting training and test data
X_train,X_test,Y_train,Y_test = train_test_split(X,Y)

# %%
sc_biased = StandardScaler()

# %%
sc_biased.fit(X_train)
# Out:
# StandardScaler()

# %%
X_train = sc_biased.transform(X_train)
X_test = sc_biased.transform(X_test)

# %%
ranfo_gini_biased = RandomForestClassifier(criterion='gini')

# %%
ranfo_gini_biased.fit(X_train,Y_train)
# Out:
# RandomForestClassifier()

# %%
Y_predict = ranfo_gini_biased.predict(X_test)

# %%
print('Random Forest(gini) Model with Biased dataset')
print('Accuracy Score is     ',accuracy_score(Y_test,Y_predict))
print('Precision Score is    ',average_precision_score(Y_test,Y_predict))
print('Recall Score is       ',recall_score(Y_test,Y_predict))
print('Confusion Metrix is   ')
print(confusion_matrix(Y_test,Y_predict))
print('F1 Score is           ',f1_score(Y_test,Y_predict))
print (classification_report(Y_test,Y_predict))
# Out:
# Random Forest(gini) Model with Biased dataset
# Accuracy Score is      0.9461735627975101
# Precision Score is     0.9581451130890075
# Recall Score is        0.9854469854469855
# Confusion Metrix is
# [[ 168  329]
#  [ 112 7584]]
# F1 Score is            0.9717470689986547
#               precision    recall  f1-score   support
#
#            0       0.60      0.34      0.43       497
#            1       0.96      0.99      0.97      7696
#
#     accuracy                           0.95      8193
#    macro avg       0.78      0.66      0.70      8193
# weighted avg       0.94      0.95      0.94      8193

# %% [markdown]
# Here the stats are facinating like -
#
# Accuracy Score is      0.9461735627975101
# Precision Score is     0.9581451130890075
# Recall Score is        0.9854469854469855
#
# But The confusion matrix is telling the truth that -
#
# 112 rows out of total 280 rows of class 0, it has predicted as class 1 which is appoximately 40%.i.e.
#
# 40% times it is predicting wrong results for class 0.

# %% [markdown]
# # Comparison between baised and unbiased prediction results

# %% [markdown]
#                                         precision    recall  f1-score   support
#
#         for Biased datset macro avg       0.78      0.66      0.70      8193
#
#     for Unbiased dataset macro avg        0.76      0.76      0.76       949

# %% [markdown]
# # clearly Unbiased dataset performs better
